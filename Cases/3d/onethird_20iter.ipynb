# %%
import numpy as np
import pylops
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
# 20 iteration

xinv = np.load('/Users/jingmingruan/Desktop/MSc/3d/xinv_2.npy')
relative = np.load('/Users/jingmingruan/Desktop/MSc/3d/relative.npy')
relative_fre = np.load('/Users/jingmingruan/Desktop/MSc/3d/relative_fre.npy')

# %%
shot = 0
fig = plt.figure(figsize = (15,8))
gs = gridspec.GridSpec(1, 3)
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])
ax3 = plt.subplot(gs[2])

ax1.imshow(xinv[:,:,shot],cmap='gray',aspect='auto')
ax1.set_xlabel('Receiver number', fontsize=20)
ax1.set_ylabel('Time sample', fontsize=20)
ax2.imshow(xinv[:,:,shot+1],cmap='gray',aspect='auto')
# ax2.set_xlabel('Receiver number', fontsize=20)
# ax2.set_ylabel('Time sample', fontsize=20)
ax3.imshow(xinv[:,:,shot+2],cmap='gray',aspect='auto')
# ax3.set_xlabel('Receiver number', fontsize=20)
# ax3.set_ylabel('Time sample', fontsize=20)

# %%
shot = 150
fig = plt.figure(figsize = (15,8))
gs = gridspec.GridSpec(1, 3)
ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])
ax3 = plt.subplot(gs[2])

ax1.imshow(xinv[:,:,shot],cmap='gray',aspect='auto')
ax1.set_xlabel('Receiver number', fontsize=20)
ax1.set_ylabel('Time sample', fontsize=20)
im1 = ax2.imshow(relative[:,:,shot],cmap='gray',aspect='auto')
cbar1 = plt.colorbar(im1)
# ax2.set_xlabel('Receiver number', fontsize=20)
# ax2.set_ylabel('Time sample', fontsize=20)
im2 = ax3.imshow(relative_fre[:,:,shot],cmap='seismic',aspect='auto')
cbar2 = plt.colorbar(im2)
# ax3.set_xlabel('Receiver number', fontsize=20)
# ax3.set_ylabel('Time sample', fontsize=20)
